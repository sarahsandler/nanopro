# %%
from load_events import load_data
from event_vis import event_vis
from event_vis import peak_event_vis
from poresize import poresize
from peaks import peak_finder
from mag_scatter import mag_scatter

# %%
file='SES23_1_500'

# %%
event_set=load_data(file)

# %%
poresize(file,2)
# Out:
# 25.2623951554559 - 2.52435489670724e-20*I

# %%
peaks=peak_finder(event_set,0.1,-0.1,8,0.03)

# %%
peaks_sorted = peaks[peaks.mag6 != 0] #sorting out other folded events for 111 barcode

# %%
sorted_events=peaks_sorted.event

# %%
#event_vis(event_set)

# %%
peak_event_vis(event_set,sorted_events)

# %%
mag_scatter(event_set,peaks_sorted)
